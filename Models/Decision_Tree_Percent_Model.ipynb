# %%
from sklearn import tree
import pandas as pd
import os

# %%
df_percent_stats = pd.read_csv("../Data/percent_stats.csv")

df_percent_stats = df_percent_stats.drop("Unnamed: 0", axis=1)
df_percent_stats = df_percent_stats.drop("Year", axis=1)
df_percent_stats
# Out:
#       Pos  TRB%  AST%  STL%  BLK%  TOV%  USG%    3P%    2P%    FT%
# 0       C  13.4  11.9   1.1   4.1  13.3  25.6  0.000  0.580  0.706
# 1       C  13.6  22.1   2.3   1.9  14.8  22.8  0.000  0.494  0.781
# 2      SF   9.7  18.6   1.2   0.9  12.7  29.8  0.352  0.475  0.680
# 3      SG   5.5  19.7   3.1   0.3  17.5  21.5  0.294  0.363  0.862
# 4      PG   2.9  31.9   1.1   0.1  18.4  17.9  0.375  0.475  0.747
# ...    ..   ...   ...   ...   ...   ...   ...    ...    ...    ...
# 16629  PF  12.9   9.1   1.8   3.0  10.9  15.5  0.000  0.572  0.679
# 16630   C  13.2  12.2   0.7   3.3  10.2  16.5  0.000  0.497  0.564
# 16631   C  17.6   5.3   0.9   3.7   8.3  14.8  0.000  0.323  0.600
# 16632  SF   8.0   6.1   0.9   1.5  14.4  14.4  0.333  0.451  0.775
# 16633   C  14.3   8.1   1.1   4.4  10.4  20.3  0.000  0.536  0.653
#
# [16634 rows x 10 columns]

# %%
target = df_percent_stats["Pos"]
target_names = ["C", "SF","SG","PF","PG"]

# %%
data = df_percent_stats.drop("Pos", axis=1)
feature_names = data.columns
data.head()
# Out:
#    TRB%  AST%  STL%  BLK%  TOV%  USG%    3P%    2P%    FT%
# 0  13.4  11.9   1.1   4.1  13.3  25.6  0.000  0.580  0.706
# 1  13.6  22.1   2.3   1.9  14.8  22.8  0.000  0.494  0.781
# 2   9.7  18.6   1.2   0.9  12.7  29.8  0.352  0.475  0.680
# 3   5.5  19.7   3.1   0.3  17.5  21.5  0.294  0.363  0.862
# 4   2.9  31.9   1.1   0.1  18.4  17.9  0.375  0.475  0.747

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data, target, random_state=42)

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# 0.5330608319307526

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=10000)
rf = rf.fit(X_train, y_train)
rf.score(X_test, y_test)
# Out:
# 0.6366915123827843

# %%
sorted(zip(rf.feature_importances_, feature_names), reverse=True)
# Out:
# [(0.22472033487841775, 'TRB%'),
#  (0.18911416766498365, 'AST%'),
#  (0.11337024404785663, 'BLK%'),
#  (0.08732993465363226, 'TOV%'),
#  (0.08613989733571709, 'USG%'),
#  (0.07940154197752634, '2P%'),
#  (0.07467570298040939, 'FT%'),
#  (0.07373060691053786, 'STL%'),
#  (0.07151756955091905, '3P%')]
