# %%
import pandas as pd

# %%
raw_stats = pd.read_csv("../Data/raw_stats.csv")

# %%
# Define the selected features for the percentage model
raw_selected_features = ['FG', 'FGA', '3P', '3PA', '2P', '2PA', 'FT', 'FTA', 'TRB', 'AST', 'STL',
       'BLK', 'TOV', 'PF', 'PTS' ]

#Define X and y sets
X = raw_stats[raw_selected_features]
y = raw_stats["Pos"]

# Split data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

#Print the X_train dataframe
X_train
# Out:
#           FG    FGA    3P    3PA     2P    2PA     FT    FTA    TRB    AST  \
# 14993  281.0  657.0  82.0  243.0  199.0  414.0  127.0  151.0  180.0  101.0
# 3371   327.0  615.0   0.0    0.0  327.0  615.0  165.0  229.0  727.0   69.0
# 2400    72.0  171.0   9.0   27.0   63.0  144.0   58.0   72.0   47.0  108.0
# 15957  267.0  517.0   0.0    4.0  267.0  513.0  215.0  335.0  628.0  226.0
# 3029    20.0   84.0   1.0    6.0   19.0   78.0   13.0   17.0   28.0   64.0
# ...      ...    ...   ...    ...    ...    ...    ...    ...    ...    ...
# 11284  262.0  602.0  50.0  122.0  212.0  480.0  150.0  170.0  229.0  156.0
# 11964   22.0   58.0   0.0    0.0   22.0   58.0   12.0   29.0  118.0   13.0
# 5390     8.0   24.0   0.0    1.0    8.0   23.0    8.0   12.0   19.0    0.0
# 860    128.0  261.0   2.0   13.0  126.0  248.0   60.0   67.0   63.0   51.0
# 15795   10.0   36.0   3.0   10.0    7.0   26.0    6.0    8.0   32.0    7.0
#
#         STL   BLK    TOV     PF    PTS
# 14993  32.0   5.0   83.0  108.0  771.0
# 3371   34.0  93.0  146.0  181.0  819.0
# 2400   11.0   6.0   50.0   35.0  211.0
# 15957  68.0  85.0  154.0  253.0  749.0
# 3029   17.0   2.0   26.0   49.0   54.0
# ...     ...   ...    ...    ...    ...
# 11284  92.0  16.0  116.0  157.0  724.0
# 11964  12.0  25.0   11.0   55.0   56.0
# 5390    2.0   6.0    7.0   14.0   24.0
# 860    22.0   4.0   52.0   67.0  318.0
# 15795   3.0   2.0    4.0    8.0   29.0
#
# [12475 rows x 15 columns]

# %%
from sklearn.preprocessing import StandardScaler

# Create a StandardScaler model and fit it to the training data
X_scaler = StandardScaler().fit(X_train)

# %%
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# One-hot encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
from tensorflow.keras.models import Sequential

model = Sequential()

# %%
from tensorflow.keras.layers import Dense
model.add(Dense(units=100, activation='relu', input_dim=15))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=5, activation='softmax'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 100)               1600
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               10100
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 505
# =================================================================
# Total params: 22,305
# Trainable params: 22,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=1
)
# Out:
# Epoch 1/100
# 390/390 [==============================] - 2s 3ms/step - loss: 1.1876 - accuracy: 0.4767
# Epoch 2/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.9049 - accuracy: 0.5947
# Epoch 3/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.8756 - accuracy: 0.6017
# Epoch 4/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.8846 - accuracy: 0.6082
# Epoch 5/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.8633 - accuracy: 0.6110
# Epoch 6/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.8803 - accuracy: 0.6121
# Epoch 7/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.8482 - accuracy: 0.6219
# Epoch 8/100
# 390/390 [==============================] - 4s 9ms/step - loss: 0.8409 - accuracy: 0.6230
# Epoch 9/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.8317 - accuracy: 0.6279
# Epoch 10/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.8290 - accuracy: 0.6268
# Epoch 11/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.8466 - accuracy: 0.6153
# Epoch 12/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.8239 - accuracy: 0.6313
# Epoch 13/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.8300 - accuracy: 0.6199
# Epoch 14/100
# 390/390 [==============================] - 3s 6ms/step - loss: 0.8158 - accuracy: 0.6428
# Epoch 15/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.8295 - accuracy: 0.6253
# Epoch 16/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.8084 - accuracy: 0.6408
# Epoch 17/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.8184 - accuracy: 0.6296
# Epoch 18/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.7910 - accuracy: 0.6418
# Epoch 19/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.7943 - accuracy: 0.6458
# Epoch 20/100
# 390/390 [==============================] - 3s 9ms/step - loss: 0.8016 - accuracy: 0.6441
# Epoch 21/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.8017 - accuracy: 0.6444
# Epoch 22/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.7860 - accuracy: 0.6452
# Epoch 23/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.7813 - accuracy: 0.6496
# Epoch 24/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.8024 - accuracy: 0.6440
# Epoch 25/100
# 390/390 [==============================] - 4s 9ms/step - loss: 0.7812 - accuracy: 0.6538
# Epoch 26/100
# 390/390 [==============================] - ETA: 0s - loss: 0.7798 - accuracy: 0.6594 ETA - 4s 10ms/step - loss: 0.7798 - accuracy: 0.6594
# Epoch 27/100
# 390/390 [==============================] - 4s 10ms/step - loss: 0.7778 - accuracy: 0.6544
# Epoch 28/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.7625 - accuracy: 0.6660
# Epoch 29/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.7691 - accuracy: 0.6568
# Epoch 30/100
# 390/390 [==============================] - 4s 10ms/step - loss: 0.7516 - accuracy: 0.6713
# Epoch 31/100
# 390/390 [==============================] - 3s 9ms/step - loss: 0.7521 - accuracy: 0.6626
# Epoch 32/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.7505 - accuracy: 0.6677
# Epoch 33/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.7475 - accuracy: 0.6702
# Epoch 34/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.7347 - accuracy: 0.6758
# Epoch 35/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.7348 - accuracy: 0.6679
# Epoch 36/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.7473 - accuracy: 0.6645
# Epoch 37/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.7373 - accuracy: 0.6780
# Epoch 38/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.7189 - accuracy: 0.6833
# Epoch 39/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.7074 - accuracy: 0.6842
# Epoch 40/100
# 390/390 [==============================] - 4s 9ms/step - loss: 0.7155 - accuracy: 0.6827
# Epoch 41/100
# 390/390 [==============================] - 5s 14ms/step - loss: 0.6910 - accuracy: 0.6929
# Epoch 42/100
# 390/390 [==============================] - 4s 11ms/step - loss: 0.7028 - accuracy: 0.6857
# Epoch 43/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.6966 - accuracy: 0.6926
# Epoch 44/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.6994 - accuracy: 0.6924
# Epoch 45/100
# 390/390 [==============================] - 4s 9ms/step - loss: 0.6946 - accuracy: 0.6895
# Epoch 46/100
# 390/390 [==============================] - 3s 9ms/step - loss: 0.6766 - accuracy: 0.6933
# Epoch 47/100
# 390/390 [==============================] - 4s 11ms/step - loss: 0.6794 - accuracy: 0.7027
# Epoch 48/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.6772 - accuracy: 0.6954
# Epoch 49/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.6827 - accuracy: 0.6980
# Epoch 50/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.6648 - accuracy: 0.7096
# Epoch 51/100
# 390/390 [==============================] - 4s 11ms/step - loss: 0.6735 - accuracy: 0.7015
# Epoch 52/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.6585 - accuracy: 0.7108
# Epoch 53/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.6623 - accuracy: 0.7049
# Epoch 54/100
# 390/390 [==============================] - 3s 9ms/step - loss: 0.6538 - accuracy: 0.7082
# Epoch 55/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.6415 - accuracy: 0.7116
# Epoch 56/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.6443 - accuracy: 0.7155
# Epoch 57/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.6239 - accuracy: 0.7267
# Epoch 58/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.6272 - accuracy: 0.7309
# Epoch 59/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.6255 - accuracy: 0.7202
# Epoch 60/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.6258 - accuracy: 0.7189
# Epoch 61/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.6230 - accuracy: 0.7263
# Epoch 62/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.6299 - accuracy: 0.7295
# Epoch 63/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.5902 - accuracy: 0.7437
# Epoch 64/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.6009 - accuracy: 0.7370
# Epoch 65/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.6001 - accuracy: 0.7291
# Epoch 66/100
# 390/390 [==============================] - 4s 9ms/step - loss: 0.6036 - accuracy: 0.7352
# Epoch 67/100
# 390/390 [==============================] - 4s 10ms/step - loss: 0.5972 - accuracy: 0.7370
# Epoch 68/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.5975 - accuracy: 0.7399
# Epoch 69/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.5909 - accuracy: 0.7405
# Epoch 70/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.5756 - accuracy: 0.7501
# Epoch 71/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.5859 - accuracy: 0.7390
# Epoch 72/100
# 390/390 [==============================] - 4s 9ms/step - loss: 0.5866 - accuracy: 0.7429
# Epoch 73/100
# 390/390 [==============================] - 3s 9ms/step - loss: 0.5730 - accuracy: 0.7449
# Epoch 74/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.5793 - accuracy: 0.7420
# Epoch 75/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.5639 - accuracy: 0.7531
# Epoch 76/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.5500 - accuracy: 0.7597
# Epoch 77/100
# 390/390 [==============================] - 3s 8ms/step - loss: 0.5697 - accuracy: 0.7579
# Epoch 78/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.5455 - accuracy: 0.7612: 2s - loss: 0.5369 - accura
# Epoch 79/100
# 390/390 [==============================] - 3s 7ms/step - loss: 0.5415 - accuracy: 0.7659
# Epoch 80/100
# 390/390 [==============================] - 1s 4ms/step - loss: 0.5483 - accuracy: 0.7578
# Epoch 81/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.5375 - accuracy: 0.7574
# Epoch 82/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.5519 - accuracy: 0.7560
# Epoch 83/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.5175 - accuracy: 0.7698
# Epoch 84/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.5306 - accuracy: 0.7673
# Epoch 85/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.5367 - accuracy: 0.7620
# Epoch 86/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.5086 - accuracy: 0.7801
# Epoch 87/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.5293 - accuracy: 0.7738
# Epoch 88/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.5148 - accuracy: 0.7748
# Epoch 89/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.4967 - accuracy: 0.7824
# Epoch 90/100
# 390/390 [==============================] - 1s 4ms/step - loss: 0.5135 - accuracy: 0.7781
# Epoch 91/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.5167 - accuracy: 0.7830
# Epoch 92/100
# 390/390 [==============================] - 1s 4ms/step - loss: 0.5004 - accuracy: 0.7846
# Epoch 93/100
# 390/390 [==============================] - 1s 4ms/step - loss: 0.5042 - accuracy: 0.7780
# Epoch 94/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.4998 - accuracy: 0.7851
# Epoch 95/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.4946 - accuracy: 0.7872
# Epoch 96/100
# 390/390 [==============================] - 3s 9ms/step - loss: 0.5062 - accuracy: 0.7791
# Epoch 97/100
# 390/390 [==============================] - 2s 5ms/step - loss: 0.4861 - accuracy: 0.7932
# Epoch 98/100
# 390/390 [==============================] - 2s 6ms/step - loss: 0.4825 - accuracy: 0.7893: 0s - loss: 0.4801 - accura
# Epoch 99/100
# 390/390 [==============================] - 1s 3ms/step - loss: 0.4801 - accuracy: 0.7963
# Epoch 100/100
# 390/390 [==============================] - 2s 4ms/step - loss: 0.4861 - accuracy: 0.7885

# %%
model_loss, model_accuracy = model.evaluate(
    X_test_scaled, y_test_categorical, verbose=1)
print(
    f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 130/130 [==============================] - 1s 6ms/step - loss: 1.3329 - accuracy: 0.5956
# Loss: 1.3328776359558105, Accuracy: 0.5955758690834045

# %%
encoded_predictions = model.predict_classes(X_test_scaled[:10])
prediction_labels = label_encoder.inverse_transform(encoded_predictions)
# Out:
# /Users/Drew/opt/anaconda3/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
print(f"Predicted classes: {prediction_labels}")
print(f"Actual Labels: {list(y_test[:10])}")
# Out:
# Predicted classes: ['C' 'SF' 'SF' 'SG' 'PF' 'SF' 'SG' 'PG' 'PF' 'C']
# Actual Labels: ['C', 'SF', 'PF', 'SG', 'SF', 'SF', 'SG', 'PG', 'PF', 'C']
